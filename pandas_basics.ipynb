# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# DATA MANIPULATION AND ANALYSIS USING PANDAS

# %%
import pandas as pd

# %% [markdown]
# Basic operations using pandas

# %%
#Creating a new DataFrame
df1=pd.DataFrame({'Name':['john','sunny','lucky','anju'],'Age':[10,12,16,14]})

# %%
df1
# Out:
#     Name  Age
# 0   john   10
# 1  sunny   12
# 2  lucky   16
# 3   anju   14

# %% [markdown]
# Data Frame is being created, where [ Name,Age ] are the names of columns

# %%
df1.columns
# Out:
# Index(['Name', 'Age'], dtype='object')

# %% [markdown]
# Loading of the data

# %%
df=pd.read_csv("C:/Users/kuruv/Downloads/bike_buyers.csv")

# %% [markdown]
# Data Exploration

# %%
df.head()
#View top rows
# Out:
#       ID Marital Status  Gender   Income  Children        Education  \
# 0  12496        Married  Female  40000.0       1.0        Bachelors
# 1  24107        Married    Male  30000.0       3.0  Partial College
# 2  14177        Married    Male  80000.0       5.0  Partial College
# 3  24381         Single     NaN  70000.0       0.0        Bachelors
# 4  25597         Single    Male  30000.0       0.0        Bachelors
#
#        Occupation Home Owner  Cars Commute Distance   Region   Age  \
# 0  Skilled Manual        Yes   0.0        0-1 Miles   Europe  42.0
# 1        Clerical        Yes   1.0        0-1 Miles   Europe  43.0
# 2    Professional         No   2.0        2-5 Miles   Europe  60.0
# 3    Professional        Yes   1.0       5-10 Miles  Pacific  41.0
# 4        Clerical         No   0.0        0-1 Miles   Europe  36.0
#
#   Purchased Bike
# 0             No
# 1             No
# 2             No
# 3            Yes
# 4            Yes

# %%
#View bottom rows
df.tail()
# Out:
#         ID Marital Status Gender    Income  Children        Education  \
# 995  23731        Married   Male   60000.0       2.0      High School
# 996  28672         Single   Male   70000.0       4.0  Graduate Degree
# 997  11809        Married    NaN   60000.0       2.0        Bachelors
# 998  19664         Single   Male  100000.0       3.0        Bachelors
# 999  12121         Single   Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# 995    Professional        Yes   2.0        2-5 Miles  North America  54.0
# 996    Professional        Yes   0.0        2-5 Miles  North America  35.0
# 997  Skilled Manual        Yes   0.0        0-1 Miles  North America  38.0
# 998      Management         No   3.0        1-2 Miles  North America  38.0
# 999    Professional        Yes   2.0        10+ Miles  North America  53.0
#
#     Purchased Bike
# 995            Yes
# 996            Yes
# 997            Yes
# ...

# %%
df.head(300)

#view first 300 rows
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 1    24107        Married    Male   30000.0       3.0  Partial College
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 3    24381         Single     NaN   70000.0       0.0        Bachelors
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 295  21557         Single  Female  110000.0       0.0  Partial College
# 296  26663         Single  Female   60000.0       2.0        Bachelors
# 297  11896        Married    Male  100000.0       1.0  Graduate Degree
# 298  14189        Married  Female   90000.0       4.0      High School
# 299  13136        Married  Female   30000.0       2.0  Partial College
#
#          Occupation Home Owner  Cars Commute Distance   Region   Age  \
# ...

# %%
df.tail(300)
#View bottom 300 rows
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 700  16795        Married  Female   70000.0       4.0        Bachelors
# 701  22014         Single    Male   30000.0       0.0      High School
# 702  13314        Married    Male  120000.0       1.0      High School
# 703  11619         Single  Female   50000.0       0.0  Graduate Degree
# 704  29132         Single  Female   40000.0       0.0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 997  11809        Married     NaN   60000.0       2.0        Bachelors
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %%
df.describe()
#Statistics Summary
# Out:
#                  ID         Income    Children        Cars         Age
# count   1000.000000     994.000000  992.000000  991.000000  992.000000
# mean   19965.992000   56267.605634    1.910282    1.455096   44.181452
# std     5347.333948   31067.817462    1.626910    1.121755   11.362007
# min    11000.000000   10000.000000    0.000000    0.000000   25.000000
# 25%    15290.750000   30000.000000    0.000000    1.000000   35.000000
# 50%    19744.000000   60000.000000    2.000000    1.000000   43.000000
# 75%    24470.750000   70000.000000    3.000000    2.000000   52.000000
# max    29447.000000  170000.000000    5.000000    4.000000   89.000000

# %%
df.dtypes
#kind of data present in each column
# Out:
# ID                    int64
# Marital Status       object
# Gender               object
# Income              float64
# Children            float64
# Education            object
# Occupation           object
# Home Owner           object
# Cars                float64
# Commute Distance     object
# Region               object
# Age                 float64
# Purchased Bike       object
# dtype: object

# %%
df.isnull().sum()
#Finding out missing values count in each and every column
# Out:
# ID                   0
# Marital Status       7
# Gender              11
# Income               6
# Children             8
# Education            0
# Occupation           0
# Home Owner           4
# Cars                 9
# Commute Distance     0
# Region               0
# Age                  8
# Purchased Bike       0
# dtype: int64

# %%
#select a particular column --->>> df["name_of_column"]
df['Gender']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3         NaN
# 4        Male
#         ...
# 995      Male
# 996      Male
# 997       NaN
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: object

# %%
df[['Gender','Children']]

#Select multiple columns --->>> df[["column_1","column_2"]]
# Out:
#      Gender  Children
# 0    Female       1.0
# 1      Male       3.0
# 2      Male       5.0
# 3       NaN       0.0
# 4      Male       0.0
# ..      ...       ...
# 995    Male       2.0
# 996    Male       4.0
# 997     NaN       2.0
# 998    Male       3.0
# 999    Male       3.0
#
# [1000 rows x 2 columns]

# %%
a=df[['Gender','Income','Cars']]

# %%
a
# Out:
#      Gender    Income  Cars
# 0    Female   40000.0   0.0
# 1      Male   30000.0   1.0
# 2      Male   80000.0   2.0
# 3       NaN   70000.0   1.0
# 4      Male   30000.0   0.0
# ..      ...       ...   ...
# 995    Male   60000.0   2.0
# 996    Male   70000.0   0.0
# 997     NaN   60000.0   0.0
# 998    Male  100000.0   3.0
# 999    Male   60000.0   2.0
#
# [1000 rows x 3 columns]

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
#Selecting rows with the help of indexing --->>> df.iloc[start_index : End_index : Jump]
df['Education'][0:50:2]
# Out:
# 0               Bachelors
# 2         Partial College
# 4               Bachelors
# 6             High School
# 8     Partial High School
# 10            High School
# 12        Partial College
# 14        Partial College
# 16        Partial College
# 18        Partial College
# 20        Graduate Degree
# 22        Partial College
# 24        Partial College
# 26        Partial College
# 28        Partial College
# 30        Partial College
# 32            High School
# 34        Partial College
# 36        Partial College
# 38            High School
# 40        Partial College
# 42        Graduate Degree
# 44            High School
# 46        Partial College
# 48        Partial College
# Name: Education, dtype: object

# %%
df[['Education', 'Age']][0:50:2]
# Out:
#               Education   Age
# 0             Bachelors  42.0
# 2       Partial College  60.0
# 4             Bachelors  36.0
# 6           High School  33.0
# 8   Partial High School  58.0
# 10          High School  54.0
# 12      Partial College  55.0
# 14      Partial College  45.0
# 16      Partial College  59.0
# 18      Partial College  35.0
# 20      Graduate Degree  36.0
# 22      Partial College  35.0
# 24      Partial College  34.0
# 26      Partial College  29.0
# 28      Partial College  44.0
# 30      Partial College  63.0
# 32          High School  31.0
# 34      Partial College  62.0
# 36      Partial College  50.0
# 38          High School  28.0
# 40      Partial College  43.0
# 42      Graduate Degree  40.0
# 44          High School  41.0
# 46      Partial College  46.0
# 48      Partial College  42.0

# %%
df.columns
#view of all the columns present in the dataset
# Out:
# Index(['ID', 'Marital Status', 'Gender', 'Income', 'Children', 'Education',
#        'Occupation', 'Home Owner', 'Cars', 'Commute Distance', 'Region', 'Age',
#        'Purchased Bike'],
#       dtype='object')

# %%
#Here we are selecting rows with the help of indexing

# iloc [1:5] ---->> Start from index 1 and go till index 4 (exclude last index from condition same like of indexing in any coding language)
df.iloc[1:10]
# Out:
#       ID Marital Status  Gender    Income  Children            Education  \
# 1  24107        Married    Male   30000.0       3.0      Partial College
# 2  14177        Married    Male   80000.0       5.0      Partial College
# 3  24381         Single     NaN   70000.0       0.0            Bachelors
# 4  25597         Single    Male   30000.0       0.0            Bachelors
# 5  13507        Married  Female   10000.0       2.0      Partial College
# 6  27974         Single    Male  160000.0       2.0          High School
# 7  19364        Married    Male   40000.0       1.0            Bachelors
# 8  22155            NaN    Male   20000.0       2.0  Partial High School
# 9  19280        Married    Male       NaN       2.0      Partial College
#
#        Occupation Home Owner  Cars Commute Distance   Region   Age  \
# 1        Clerical        Yes   1.0        0-1 Miles   Europe  43.0
# 2    Professional         No   2.0        2-5 Miles   Europe  60.0
# ...

# %%
#start from 0th index and go till 4th index
df.iloc[0:10]
# Out:
#       ID Marital Status  Gender    Income  Children            Education  \
# 0  12496        Married  Female   40000.0       1.0            Bachelors
# 1  24107        Married    Male   30000.0       3.0      Partial College
# 2  14177        Married    Male   80000.0       5.0      Partial College
# 3  24381         Single     NaN   70000.0       0.0            Bachelors
# 4  25597         Single    Male   30000.0       0.0            Bachelors
# 5  13507        Married  Female   10000.0       2.0      Partial College
# 6  27974         Single    Male  160000.0       2.0          High School
# 7  19364        Married    Male   40000.0       1.0            Bachelors
# 8  22155            NaN    Male   20000.0       2.0  Partial High School
# 9  19280        Married    Male       NaN       2.0      Partial College
#
#        Occupation Home Owner  Cars Commute Distance   Region   Age  \
# 0  Skilled Manual        Yes   0.0        0-1 Miles   Europe  42.0
# ...

# %%
df['Income']>30000
# Out:
# 0       True
# 1      False
# 2       True
# 3       True
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Income, Length: 1000, dtype: bool

# %%
#Accesing of entire rows with the condition for particular column

# df[df['column_name']condition]

df[df['Income']>30000]
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 3    24381         Single     NaN   70000.0       0.0        Bachelors
# 6    27974         Single    Male  160000.0       2.0      High School
# 7    19364        Married    Male   40000.0       1.0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 997  11809        Married     NaN   60000.0       2.0        Bachelors
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %% [markdown]
# Data Manipulation

# %%
#Adding of new column :
df['new_col1']=df['Education'] + df['Occupation']

# %%
df
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 1    24107        Married    Male   30000.0       3.0  Partial College
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 3    24381         Single     NaN   70000.0       0.0        Bachelors
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 997  11809        Married     NaN   60000.0       2.0        Bachelors
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %%
df['new_col2']=df['Commute Distance'] + df['Region']

# %%
df
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 1    24107        Married    Male   30000.0       3.0  Partial College
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 3    24381         Single     NaN   70000.0       0.0        Bachelors
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 997  11809        Married     NaN   60000.0       2.0        Bachelors
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %%
df['new_col3']=df['ID'] + df['Purchased Bike']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:131, in _evaluate_numexpr(op, op_str, a, b)
#     130 if result is None:
# --> 131     result = _evaluate_standard(op, op_str, a, b)
#     133 return result
#
# ...

# %% [markdown]
# We are encountering with error message because its not possible to combine a string data type with other data types.

# %%
df['new_col3']=df['ID'] + df['Cars']

# %%
df
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 1    24107        Married    Male   30000.0       3.0  Partial College
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 3    24381         Single     NaN   70000.0       0.0        Bachelors
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 997  11809        Married     NaN   60000.0       2.0        Bachelors
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %%
df.dtypes
# Out:
# ID                    int64
# Marital Status       object
# Gender               object
# Income              float64
# Children            float64
# Education            object
# Occupation           object
# Home Owner           object
# Cars                float64
# Commute Distance     object
# Region               object
# Age                 float64
# Purchased Bike       object
# new_col1             object
# new_col2             object
# new_col3            float64
# dtype: object

# %% [markdown]
# We can observe that three columns are being added

# %%
# Now we ae deleting the newly added columns
df = df.drop(['new_col1','new_col2','new_col3'],axis=1)

# %%
df
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 1    24107        Married    Male   30000.0       3.0  Partial College
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 3    24381         Single     NaN   70000.0       0.0        Bachelors
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 997  11809        Married     NaN   60000.0       2.0        Bachelors
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region   Age  \
# ...

# %%
df.columns
#view of all the columns present in the dataset
# Out:
# Index(['ID', 'Marital Status', 'Gender', 'Income', 'Children', 'Education',
#        'Occupation', 'Home Owner', 'Cars', 'Commute Distance', 'Region', 'Age',
#        'Purchased Bike'],
#       dtype='object')

# %%
df.shape
#Get the dimensions of the dataframe
# Out:
# (1000, 13)

# %%
df.info()
#Get a concise summary of DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1000 non-null   int64
#  1   Marital Status    993 non-null    object
#  2   Gender            989 non-null    object
#  3   Income            994 non-null    float64
#  4   Children          992 non-null    float64
#  5   Education         1000 non-null   object
#  6   Occupation        1000 non-null   object
#  7   Home Owner        996 non-null    object
#  8   Cars              991 non-null    float64
#  9   Commute Distance  1000 non-null   object
#  10  Region            1000 non-null   object
#  11  Age               992 non-null    float64
#  12  Purchased Bike    1000 non-null   object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 101.7+ KB

# %%
#Renaming of the columns
df = df.rename(columns={'Home Owner':'Owner of the House'})

# %%
df
# Out:
#         ID Marital Status  Gender    Income  Children        Education  \
# 0    12496        Married  Female   40000.0       1.0        Bachelors
# 1    24107        Married    Male   30000.0       3.0  Partial College
# 2    14177        Married    Male   80000.0       5.0  Partial College
# 3    24381         Single     NaN   70000.0       0.0        Bachelors
# 4    25597         Single    Male   30000.0       0.0        Bachelors
# ..     ...            ...     ...       ...       ...              ...
# 995  23731        Married    Male   60000.0       2.0      High School
# 996  28672         Single    Male   70000.0       4.0  Graduate Degree
# 997  11809        Married     NaN   60000.0       2.0        Bachelors
# 998  19664         Single    Male  100000.0       3.0        Bachelors
# 999  12121         Single    Male   60000.0       3.0      High School
#
#          Occupation Owner of the House  Cars Commute Distance         Region  \
# ...

# %%
df['Owner of the House'][1:9]
# Out:
# 1    Yes
# 2     No
# 3    Yes
# 4     No
# 5    Yes
# 6    NaN
# 7    Yes
# 8    Yes
# Name: Owner of the House, dtype: object
